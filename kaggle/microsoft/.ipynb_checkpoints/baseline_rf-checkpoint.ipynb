# %% [markdown]
# # Create baseline random forest model
#
# This is a first pass on the Microsoft malware Kaggle competition. This notebook creates a baseline model using sklearns random forest classifier to offer a gauge on how well future models are performing.
#
# We'll also use this notebook to get a initial view of the feature importance in this dataset.

# %%
import os
import random
import feather

import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
# Out:
# /Users/samcleary/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
data_path_training = 'data/train.csv'

# %% [markdown]
# The training data set has already been loaded and saved to a feather format in the raw_data_to_feather notebook. This reduces the load time of the full training set from ~2mins to ~1min. The full training set is ~7.5gb of data which is starting to put pressure on the memory on my laptop. Will need to consider how to approach working with datasets of this size particularly when we want to pull in the test set of data.

# %%
#%time train_df = feather.read_dataframe(data_path_training)

# %% [markdown]
# ### Issues with file size
#
# The 7.5gb size of the full training set has been causing issues on my local machine. Instead we'll use a sample of the training data for local development and then run the full set on a cloud instance when ready.
#
# Using exp1orer's answer from this stackoverflow question: https://stackoverflow.com/questions/22258491/read-a-small-random-sample-from-a-big-csv-file-into-a-python-data-frame
#
# At this stage we'll work with 1% of the training data. Note: each time this is run it will take a different sample.

# %%
# %time train_df = pd.read_csv(data_path_training, header = 0, skiprows = lambda i: i > 0 and random.random() > 0.01)
# Out:
# <string>:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 1min 42s, sys: 32.9 s, total: 2min 15s
# Wall time: 2min 13s

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Initial overview of data
#
# The training dataset contains ~9 million rows of data each containing 83 features. The set is divided almost exactly in half of examples with and without malware detected.

# %%
train_df.shape
# Out:
# (8921483, 83)

# %%
train_df.HasDetections.value_counts()
# Out:
# 0    4462591
# 1    4458892
# Name: HasDetections, dtype: int64

# %%
train_df.head(2).T
# Out:
#                                                                                           0  \
# MachineIdentifier                                          0000028988387b115f69f31a3bf04f09
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.15100.1
# AppVersion                                                                  4.18.1807.18075
# AvSigVersion                                                                   1.273.1735.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                          7
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                             53447
# AVProductsInstalled                                                                       1
# AVProductsEnabled                                                                         1
# HasTpm                                                                                    1
# CountryIdentifier                                                                        29
# CityIdentifier                                                                       128035
# OrganizationIdentifier                                                                   18
# GeoNameIdentifier                                                                        35
# LocaleEnglishNameIdentifier                                                             171
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 256
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                              Pro
# IsProtected                                                                               1
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                     0
# IeVerIdentifier                                                                         137
# SmartScreen                                                                             NaN
# Firewall                                                                                  1
# UacLuaenable                                                                              1
# Census_MDC2FormFactor                                                               Desktop
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                               2668
# Census_OEMModelIdentifier                                                              9124
# Census_ProcessorCoreCount                                                                 4
# Census_ProcessorManufacturerIdentifier                                                    5
# Census_ProcessorModelIdentifier                                                        2341
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                      476940
# Census_PrimaryDiskTypeName                                                              HDD
# Census_SystemVolumeTotalCapacity                                                     299451
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                                4096
# Census_ChassisTypeName                                                              Desktop
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      18.9
# Census_InternalPrimaryDisplayResolutionHorizontal                                      1440
# Census_InternalPrimaryDisplayResolutionVertical                                         900
# Census_PowerPlatformRoleName                                                        Desktop
# Census_InternalBatteryType                                                              NaN
# Census_InternalBatteryNumberOfCharges                                           4.29497e+09
# Census_OSVersion                                                             10.0.17134.165
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                  165
# Census_OSEdition                                                               Professional
# Census_OSSkuName                                                               PROFESSIONAL
# Census_OSInstallTypeName                                                         UUPUpgrade
# Census_OSInstallLanguageIdentifier                                                       26
# Census_OSUILocaleIdentifier                                                             119
# Census_OSWUAutoUpdateOptionsName                                                    UNKNOWN
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                          IS_GENUINE
# Census_ActivationChannel                                                             Retail
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                  0
# Census_FlightRing                                                                    Retail
# Census_ThresholdOptIn                                                                   NaN
# Census_FirmwareManufacturerIdentifier                                                   628
# Census_FirmwareVersionIdentifier                                                      36144
# Census_IsSecureBootEnabled                                                                0
# Census_IsWIMBootEnabled                                                                 NaN
# Census_IsVirtualDevice                                                                    0
# Census_IsTouchEnabled                                                                     0
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                   0
# Wdft_IsGamer                                                                              0
# Wdft_RegionIdentifier                                                                    10
# HasDetections                                                                             0
#
#                                                                                           1
# MachineIdentifier                                          000007535c3f730efa9ea0b7ef1bd645
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.14600.4
# AppVersion                                                                     4.13.17134.1
# AvSigVersion                                                                     1.263.48.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                          7
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                             53447
# AVProductsInstalled                                                                       1
# AVProductsEnabled                                                                         1
# HasTpm                                                                                    1
# CountryIdentifier                                                                        93
# CityIdentifier                                                                         1482
# OrganizationIdentifier                                                                   18
# GeoNameIdentifier                                                                       119
# LocaleEnglishNameIdentifier                                                              64
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 256
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                              Pro
# IsProtected                                                                               1
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                     0
# IeVerIdentifier                                                                         137
# SmartScreen                                                                             NaN
# Firewall                                                                                  1
# UacLuaenable                                                                              1
# Census_MDC2FormFactor                                                              Notebook
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                               2668
# Census_OEMModelIdentifier                                                             91656
# Census_ProcessorCoreCount                                                                 4
# Census_ProcessorManufacturerIdentifier                                                    5
# Census_ProcessorModelIdentifier                                                        2405
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                      476940
# Census_PrimaryDiskTypeName                                                              HDD
# Census_SystemVolumeTotalCapacity                                                     102385
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                                4096
# Census_ChassisTypeName                                                             Notebook
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      13.9
# Census_InternalPrimaryDisplayResolutionHorizontal                                      1366
# Census_InternalPrimaryDisplayResolutionVertical                                         768
# Census_PowerPlatformRoleName                                                         Mobile
# Census_InternalBatteryType                                                              NaN
# Census_InternalBatteryNumberOfCharges                                                     1
# Census_OSVersion                                                               10.0.17134.1
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                    1
# Census_OSEdition                                                               Professional
# Census_OSSkuName                                                               PROFESSIONAL
# Census_OSInstallTypeName                                                           IBSClean
# Census_OSInstallLanguageIdentifier                                                        8
# Census_OSUILocaleIdentifier                                                              31
# Census_OSWUAutoUpdateOptionsName                                                    UNKNOWN
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                             OFFLINE
# Census_ActivationChannel                                                             Retail
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                  0
# Census_FlightRing                                                                   NOT_SET
# Census_ThresholdOptIn                                                                   NaN
# Census_FirmwareManufacturerIdentifier                                                   628
# Census_FirmwareVersionIdentifier                                                      57858
# Census_IsSecureBootEnabled                                                                0
# Census_IsWIMBootEnabled                                                                 NaN
# Census_IsVirtualDevice                                                                    0
# Census_IsTouchEnabled                                                                     0
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                   0
# Wdft_IsGamer                                                                              0
# Wdft_RegionIdentifier                                                                     8
# HasDetections                                                                             0

# %% [markdown]
# ## Preprocessing training data for Random Forest
#
# All of the features need to be converted to numbers to work in the random forest. We need to identify which columns hold values that are not numbers (expect all of these values to be strings) and then decide whether to one hot encode or linear encode the features.
#
# For features that have low enough value types we will one hot encode, the others we will pass through a linear encoder.
#
# #### Potential problem
# These counts of the number of values in each feature may not hold true in the full training set.
#
# #### Results from full training set
# When running this code over the full traing set this was the result from a limit of 30
#
# "After one hot encoding features with less than 30 values there will be 208 features in the training set"
#
# A limit of 35 results in:
#
# "After one hot encoding features with less than 35 values there will be 303 features in the training set"

# %%
non_numerical_features_names = list(train_df.select_dtypes(include=["object"]).columns)

non_numerical_features = pd.DataFrame(index=non_numerical_features_names)
non_numerical_features['occurences'] = np.nan

for feat in non_numerical_features_names:
    non_numerical_features.loc[feat, 'occurences'] = train_df[feat].value_counts().count()

# %%
feature_limit_one_hot_encode = 35

non_numerical_features.sort_values(by='occurences', ascending=False, inplace=True)
non_numerical_features['oh_encode'] = non_numerical_features['occurences'].apply(lambda row: True if row < feature_limit_one_hot_encode else False)

# %%
print(
    'After one hot encoding features with less than ' + str(feature_limit_one_hot_encode) + ' values there will be '
    + str(int(train_df.shape[1] + non_numerical_features.occurences.where(non_numerical_features.oh_encode).sum()))
    + ' features in the training set'
)
# Out:
# After one hot encoding features with less than 35 values there will be 303 features in the training set

# %%
non_numerical_features
# Out:
#                                   occurences  oh_encode
# MachineIdentifier                  8921483.0      False
# AvSigVersion                          8531.0      False
# OsBuildLab                             663.0      False
# Census_OSVersion                       469.0      False
# AppVersion                             110.0      False
# Census_InternalBatteryType              78.0      False
# EngineVersion                           70.0      False
# OsVer                                   58.0      False
# Census_ChassisTypeName                  52.0      False
# Census_OSEdition                        33.0       True
# Census_OSBranch                         32.0       True
# Census_OSSkuName                        30.0       True
# SmartScreen                             21.0       True
# Census_MDC2FormFactor                   13.0       True
# Census_FlightRing                       10.0       True
# Census_PowerPlatformRoleName            10.0       True
# OsPlatformSubRelease                     9.0       True
# Census_OSInstallTypeName                 9.0       True
# SkuEdition                               8.0       True
# ProductName                              6.0       True
# Census_OSWUAutoUpdateOptionsName         6.0       True
# Census_ActivationChannel                 6.0       True
# Census_GenuineStateName                  5.0       True
# Census_PrimaryDiskTypeName               4.0       True
# Platform                                 4.0       True
# Census_DeviceFamily                      3.0       True
# Census_OSArchitecture                    3.0       True
# Processor                                3.0       True
# Census_ProcessorClass                    3.0       True
# PuaMode                                  2.0       True
